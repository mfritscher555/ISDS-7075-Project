# %% [markdown]
# # Predicting Energy Consumption
#
# In the dataset, there are energy levels recorded for 15 different power plants for each hour in the day; i.e., there are 24 variables, in addition to ID columns, such as date and plant ID.
#
# In the temperature dataset, there are temperatures recorded for 9 different stations for each hour in the day, i.e., there are 24 variables.
#
# This predicition model will simply attempt to predict loads based on loads from the other 23 hours, without considering temperatures as variables

# %%
# imports

import numpy as np
import pandas as pd
import tensorflow as tf
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense, Dropout
from matplotlib import pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import seaborn as sns
from keras.constraints import nonneg

# %%
energy = pd.read_excel('C://Users//Matthew//PycharmProjects//ISDS-7075-Project//final_project//datasets//dataset.xlsx')

# %%
energy = energy.iloc[0:,0:28]

energy = energy[energy.obsn != 'total']
# Out:
#    obsn  year  month  day        h1        h2        h3        h4        h5  \
# 0     1  2015      1    1   66025.0   64655.0   63898.0   64078.0   65734.0
# 1     2  2015      1    1   16908.0   16505.0   16572.0   16928.0   17119.0
# 2     3  2015      1    1  126314.0  123368.0  119247.0  117562.0  118398.0
# 3     4  2015      1    1  136288.0  133110.0  128663.0  126846.0  127747.0
# 4     5  2015      1    1     539.0     512.0     505.0     503.0     499.0
# 5     6  2015      1    1    6884.0    6651.0    6580.0    6709.0    7032.0
# 6     7  2015      1    1  133143.0  129964.0  125772.0  124217.0  125375.0
# 7     8  2015      1    1  136288.0  133110.0  128663.0  126846.0  127747.0
# 8     9  2015      1    1    3179.0    3011.0    3008.0    2969.0    3276.0
# 9    10  2015      1    1   75298.0   67423.0   64105.0   63916.0   75907.0
# 10   11  2015      1    1   23394.0   22155.0   21431.0   21390.0   21619.0
# 11   12  2015      1    1   90755.0   86754.0   84298.0   84340.0   86142.0
# 12   13  2015      1    1  118433.0  112535.0  108490.0  107279.0  108925.0
# 13   14  2015      1    1   20728.0   19721.0   19075.0   18896.0   19365.0
# 14   15  2015      1    1   21846.0   21455.0   21053.0   21269.0   21885.0
# 16   16  2015      1    2   57097.0   54532.0   52377.0   52239.0   54898.0
# 17   17  2015      1    2   14210.0   14093.0   14074.0   14544.0   14975.0
# 18   18  2015      1    2  123507.0  122362.0  122236.0  123457.0  125808.0
# 19   19  2015      1    2  133261.0  132025.0  131888.0  133207.0  135742.0
# 20   20  2015      1    2     516.0     493.0     502.0     494.0     503.0
#
#           h6  ...       h15       h16       h17       h18       h19       h20  \
# 0    63360.0  ...   50102.0   49364.0   51966.0   60480.0   64995.0   65275.0
# 1    17782.0  ...   13573.0   13193.0   14185.0   16864.0   18205.0   18290.0
# 2   121283.0  ...  127738.0  126884.0  135218.0  155491.0  157905.0  156895.0
# 3   130860.0  ...  137825.0  136904.0  145897.0  167770.0  170376.0  169285.0
# 4      545.0  ...     581.0     562.0     615.0     674.0     748.0     718.0
# 5     7385.0  ...    6913.0    6690.0    7275.0    8713.0    9234.0    9160.0
# 6   128613.0  ...  134595.0  133520.0  142438.0  164148.0  167084.0  166000.0
# 7   130860.0  ...  137825.0  136904.0  145897.0  167770.0  170376.0  169285.0
# 8     3416.0  ...    3829.0    3808.0    3958.0    4403.0    4663.0    4587.0
# 9    80044.0  ...   65722.0   65680.0   64987.0   66184.0   65176.0   64966.0
# 10   22296.0  ...   20177.0   20128.0   21185.0   24880.0   26482.0   26516.0
# 11   90265.0  ...   84570.0   83113.0   88278.0  105115.0  111353.0  112782.0
# 12  112450.0  ...  111541.0  109659.0  117167.0  140692.0  148971.0  151149.0
# 13   19470.0  ...   20086.0   20079.0   21385.0   24125.0   24711.0   24350.0
# 14   21849.0  ...   16438.0   16386.0   17741.0   21611.0   23378.0   23614.0
# 16   55357.0  ...   52851.0   52079.0   53004.0   60382.0   65371.0   64864.0
# 17   16127.0  ...   16182.0   15503.0   15894.0   17782.0   18950.0   18705.0
# 18  136600.0  ...  158403.0  152886.0  157984.0  173045.0  173483.0  170236.0
# 19  147388.0  ...  170913.0  164961.0  170461.0  186711.0  187184.0  183680.0
# 20     540.0  ...     577.0     545.0     559.0     639.0     685.0     689.0
#
#          h21       h22       h23       h24
# 0    65167.0   65055.0   65449.0   61156.0
# 1    17980.0   16959.0   16217.0   14805.0
# 2   153409.0  147031.0  137768.0  128078.0
# 3   165525.0  158642.0  148647.0  138193.0
# 4      692.0     660.0     605.0     577.0
# 5     8826.0    8277.0    7360.0    6391.0
# 6   162181.0  155252.0  145073.0  134415.0
# 7   165525.0  158642.0  148647.0  138193.0
# 8     4327.0    3959.0    3582.0    3243.0
# 9    64966.0   65407.0   73660.0   76537.0
# 10   26255.0   25433.0   23881.0   22081.0
# 11  111668.0  107977.0  101566.0   93259.0
# 12  150370.0  145129.0  136564.0  124318.0
# 13   23715.0   22445.0   21827.0   19740.0
# 14   23940.0   23321.0   23306.0   21507.0
# 16   64175.0   62627.0   63434.0   60385.0
# 17   18498.0   17635.0   16522.0   15313.0
# 18  166236.0  158411.0  148475.0  138555.0
# 19  179365.0  170922.0  160200.0  149497.0
# 20     640.0     657.0     608.0     536.0
#
# [20 rows x 28 columns]

# %%
temps = pd.read_excel(r"C:\Users\Matthew\PycharmProjects\ISDS-7075-Project\final_project\datasets\dataset.xlsx",
                      sheet_name="temperature_history")

# %% [markdown]
# Returning the average temperatures for each day for each hour

# %%
def avg(column_index, dataframe):
    data_you_want = dataframe.iloc[:,column_index]
    daily_averages = list()

    #creates array for u wind values
    for i,d in enumerate(data_you_want):
        if (i % 9) == 0:
            avg_for_day = np.mean(data_you_want[i - 9:i])
            daily_averages.append(avg_for_day)
            
    return daily_averages

# %%
# Calling function and recreating dataframe to just contain average temperatures for each hour of each day
h1 = avg(5, temps)
h2 = avg(6, temps)
h3 = avg(7, temps)
h4 = avg(8, temps)
h5 = avg(9, temps)
h6 = avg(10, temps)
h7 = avg(11, temps)
h8 = avg(12, temps)
h9 = avg(13, temps)
h10 = avg(14, temps)
h11 = avg(15, temps)
h12 = avg(16, temps)
h13 = avg(17, temps)
h14 = avg(18, temps)
h15 = avg(19, temps)
h16 = avg(20, temps)
h17 = avg(21, temps)
h18 = avg(22, temps)
h19 = avg(23, temps)
h20 = avg(24, temps)
h21 = avg(25, temps)
h22 = avg(26, temps)
h23 = avg(27, temps)
h24 = avg(28, temps)




d = {'h1': h1, 'h2': h2, 'h3': h3, 'h4': h4, 'h5': h5, 'h6': h6, 'h7': h7, 'h8': h8,
    'h9': h9, 'h10': h10, 'h11': h11, 'h12': h12, 'h13': h13, 'h14': h14, 'h15': h15, 'h16': h16,
    'h17': h17, 'h18': h18, 'h19': h19, 'h20': h20, 'h21': h21, 'h22': h22, 'h23': h23, 'h24': h24}

df = pd.DataFrame(data=d)    


# df.to_excel('average_temps.xlsx')

# %% [markdown]
# I went in and put in the predicted temps into the same file in a new sheet; we will run the same function to return the averages

# %%
# temp_pred = pd.read_excel(r"C:\Users\Matthew\PycharmProjects\ISDS-7075-Project\final_project\predictive_models\average_temps.xlsx",
#                       sheet_name="temp_predictions")

# %%
h1 = avg(1, temp_pred)
h2 = avg(2, temp_pred)
h3 = avg(3, temp_pred)
h4 = avg(4, temp_pred)
h5 = avg(5, temp_pred)
h6 = avg(6, temp_pred)
h7 = avg(7, temp_pred)
h8 = avg(8, temp_pred)
h9 = avg(9, temp_pred)
h10 = avg(10, temp_pred)
h11 = avg(11, temp_pred)
h12 = avg(12, temp_pred)
h13 = avg(13, temp_pred)
h14 = avg(14, temp_pred)
h15 = avg(15, temp_pred)
h16 = avg(16, temp_pred)
h17 = avg(17, temp_pred)
h18 = avg(18, temp_pred)
h19 = avg(19, temp_pred)
h20 = avg(20, temp_pred)
h21 = avg(21, temp_pred)
h22 = avg(22, temp_pred)
h23 = avg(23, temp_pred)
h24 = avg(24, temp_pred)



d = {'h1': h1, 'h2': h2, 'h3': h3, 'h4': h4, 'h5': h5, 'h6': h6, 'h7': h7, 'h8': h8,
    'h9': h9, 'h10': h10, 'h11': h11, 'h12': h12, 'h13': h13, 'h14': h14, 'h15': h15, 'h16': h16,
    'h17': h17, 'h18': h18, 'h19': h19, 'h20': h20, 'h21': h21, 'h22': h22, 'h23': h23, 'h24': h24}

df_new = pd.DataFrame(data=d)    

# df_new.to_excel('average_temp_pred.xlsx')

# %% [markdown]
# Manually reinserted these averages into the average_temps.xlsx file

# %%
# Created a date column in Excel
avg_temps = pd.read_excel('average_temps.xlsx', sheet_name='Sheet1')

# %%
# Creating a date field
energy["date"] = pd.to_datetime(energy[["year", "month", "day"]], format='%Y-%m-%d', errors='coerce')

# energy.info()


# Leap year values are causing problems.... manually replacing
# temps["date"].fillna('2015-02-29', inplace=True)


train_dates = energy["date"]
# print(train_dates.info())

# %% [markdown]
# Joining the average temperatures with the energy based on date

# %%
merged = energy.merge(right=avg_temps, how='outer', left_on='date', right_on='date')

merged.info(verbose=True)


# merged.to_csv('merged(1).csv')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 24632 entries, 0 to 24631
# Data columns (total 54 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   obsn        24630 non-null  object
#  1   year        24630 non-null  float64
#  2   month       24630 non-null  float64
#  3   day         24630 non-null  float64
#  4   h1_x        23685 non-null  float64
#  5   h2_x        23685 non-null  float64
#  6   h3_x        23685 non-null  float64
#  7   h4_x        23685 non-null  float64
#  8   h5_x        23685 non-null  float64
#  9   h6_x        23685 non-null  float64
#  10  h7_x        23685 non-null  float64
#  11  h8_x        23685 non-null  float64
#  12  h9_x        23685 non-null  float64
#  13  h10_x       23685 non-null  float64
#  14  h11_x       23685 non-null  float64
#  15  h12_x       23685 non-null  float64
#  16  h13_x       23685 non-null  float64
#  17  h14_x       23685 non-null  float64
#  18  h15_x       23685 non-null  float64
#  19  h16_x       23685 non-null  float64
#  20  h17_x       23685 non-null  float64
#  21  h18_x       23685 non-null  float64
#  22  h19_x       23685 non-null  float64
#  23  h20_x       23685 non-null  float64
#  24  h21_x       23685 non-null  float64
#  25  h22_x       23685 non-null  float64
#  26  h23_x       23685 non-null  float64
#  27  h24_x       23685 non-null  float64
#  28  date        24602 non-null  datetime64[ns]
#  29  Unnamed: 0  24602 non-null  float64
#  30  h1_y        24587 non-null  float64
#  31  h2_y        24587 non-null  float64
#  32  h3_y        24587 non-null  float64
#  33  h4_y        24587 non-null  float64
#  34  h5_y        24587 non-null  float64
#  35  h6_y        24587 non-null  float64
#  36  h7_y        24587 non-null  float64
#  37  h8_y        24587 non-null  float64
#  38  h9_y        24587 non-null  float64
#  39  h10_y       24587 non-null  float64
#  40  h11_y       24587 non-null  float64
#  41  h12_y       24587 non-null  float64
#  42  h13_y       24587 non-null  float64
#  43  h14_y       24587 non-null  float64
#  44  h15_y       24587 non-null  float64
#  45  h16_y       24587 non-null  float64
#  46  h17_y       24587 non-null  float64
#  47  h18_y       24587 non-null  float64
#  48  h19_y       24587 non-null  float64
#  49  h20_y       24587 non-null  float64
#  50  h21_y       24587 non-null  float64
#  51  h22_y       24587 non-null  float64
#  52  h23_y       24587 non-null  float64
#  53  h24_y       24587 non-null  float64
# dtypes: datetime64[ns](1), float64(52), object(1)
# memory usage: 10.3+ MB

# %%
merged = pd.read_csv('merged(1).csv')
merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24602 entries, 0 to 24601
# Data columns (total 55 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0.1  24602 non-null  int64
#  1   obsn          24600 non-null  float64
#  2   year          24600 non-null  float64
#  3   month         24600 non-null  float64
#  4   day           24600 non-null  float64
#  5   h1_x          23655 non-null  float64
#  6   h2_x          23655 non-null  float64
#  7   h3_x          23655 non-null  float64
#  8   h4_x          23655 non-null  float64
#  9   h5_x          23655 non-null  float64
#  10  h6_x          23655 non-null  float64
#  11  h7_x          23655 non-null  float64
#  12  h8_x          23655 non-null  float64
#  13  h9_x          23655 non-null  float64
#  14  h10_x         23655 non-null  float64
#  15  h11_x         23655 non-null  float64
#  16  h12_x         23655 non-null  float64
#  17  h13_x         23655 non-null  float64
#  18  h14_x         23655 non-null  float64
#  19  h15_x         23655 non-null  float64
#  20  h16_x         23655 non-null  float64
#  21  h17_x         23655 non-null  float64
#  22  h18_x         23655 non-null  float64
#  23  h19_x         23655 non-null  float64
#  24  h20_x         23655 non-null  float64
#  25  h21_x         23655 non-null  float64
#  26  h22_x         23655 non-null  float64
#  27  h23_x         23655 non-null  float64
#  28  h24_x         23655 non-null  float64
#  29  date          24602 non-null  object
#  30  Unnamed: 0    24602 non-null  int64
#  31  h1_y          24602 non-null  float64
#  32  h2_y          24602 non-null  float64
#  33  h3_y          24602 non-null  float64
#  34  h4_y          24602 non-null  float64
#  35  h5_y          24602 non-null  float64
#  36  h6_y          24602 non-null  float64
#  37  h7_y          24602 non-null  float64
#  38  h8_y          24602 non-null  float64
#  39  h9_y          24602 non-null  float64
#  40  h10_y         24602 non-null  float64
#  41  h11_y         24602 non-null  float64
#  42  h12_y         24602 non-null  float64
#  43  h13_y         24602 non-null  float64
#  44  h14_y         24602 non-null  float64
#  45  h15_y         24602 non-null  float64
#  46  h16_y         24602 non-null  float64
#  47  h17_y         24602 non-null  float64
#  48  h18_y         24602 non-null  float64
#  49  h19_y         24602 non-null  float64
#  50  h20_y         24602 non-null  float64
#  51  h21_y         24602 non-null  float64
#  52  h22_y         24602 non-null  float64
#  53  h23_y         24602 non-null  float64
#  54  h24_y         24602 non-null  float64
# dtypes: float64(52), int64(2), object(1)
# memory usage: 10.3+ MB

# %%
# cols = list(merged)[5:28, 46:69]

cols = list(merged.loc[:, ~merged.columns.isin(['Unnamed: 0', 'date'])])
cols = list(cols)[5:70]

# print(cols)

df_for_training = merged.loc[0:6897,cols].astype(float)
df_for_training.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6898 entries, 0 to 6897
# Data columns (total 48 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   h1_x    6793 non-null   float64
#  1   h2_x    6793 non-null   float64
#  2   h3_x    6793 non-null   float64
#  3   h4_x    6793 non-null   float64
#  4   h5_x    6793 non-null   float64
#  5   h6_x    6793 non-null   float64
#  6   h7_x    6793 non-null   float64
#  7   h8_x    6793 non-null   float64
#  8   h9_x    6793 non-null   float64
#  9   h10_x   6793 non-null   float64
#  10  h11_x   6793 non-null   float64
#  11  h12_x   6793 non-null   float64
#  12  h13_x   6793 non-null   float64
#  13  h14_x   6793 non-null   float64
#  14  h15_x   6793 non-null   float64
#  15  h16_x   6793 non-null   float64
#  16  h17_x   6793 non-null   float64
#  17  h18_x   6793 non-null   float64
#  18  h19_x   6793 non-null   float64
#  19  h20_x   6793 non-null   float64
#  20  h21_x   6793 non-null   float64
#  21  h22_x   6793 non-null   float64
#  22  h23_x   6793 non-null   float64
#  23  h24_x   6793 non-null   float64
#  24  h1_y    6898 non-null   float64
#  25  h2_y    6898 non-null   float64
#  26  h3_y    6898 non-null   float64
#  27  h4_y    6898 non-null   float64
#  28  h5_y    6898 non-null   float64
#  29  h6_y    6898 non-null   float64
#  30  h7_y    6898 non-null   float64
#  31  h8_y    6898 non-null   float64
#  32  h9_y    6898 non-null   float64
#  33  h10_y   6898 non-null   float64
#  34  h11_y   6898 non-null   float64
#  35  h12_y   6898 non-null   float64
#  36  h13_y   6898 non-null   float64
#  37  h14_y   6898 non-null   float64
#  38  h15_y   6898 non-null   float64
#  39  h16_y   6898 non-null   float64
#  40  h17_y   6898 non-null   float64
#  41  h18_y   6898 non-null   float64
#  42  h19_y   6898 non-null   float64
#  43  h20_y   6898 non-null   float64
#  44  h21_y   6898 non-null   float64
#  45  h22_y   6898 non-null   float64
#  46  h23_y   6898 non-null   float64
#  47  h24_y   6898 non-null   float64
# dtypes: float64(48)
# memory usage: 2.5 MB

# %% [markdown]
# Use h1_y to predict h1_x, etc.

# %%
# LTSM uses sigmoid and tanh that are sensitive to magnitude, so values need to be normalized
scaler = StandardScaler()
scaler = scaler.fit(df_for_training)
df_for_training_scaled = scaler.transform(df_for_training)

# %%
trainX = []
trainY = []


n_future = 7
n_past = 21



for i in range(n_past, len(df_for_training_scaled) - n_future + 1):
    trainX.append(df_for_training_scaled[i - n_past:i, 0:df_for_training.shape[1]])
    trainY.append(df_for_training_scaled[i + n_future - 1:i + n_future, 0])

trainX, trainY = np.array(trainX), np.array(trainY)

# %%
# define Autoencoder model

model = Sequential()
model.add(LSTM(64, activation='relu', input_shape=(trainX.shape[1], trainX.shape[2]), return_sequences=True))
model.add(LSTM(32, activation='relu', return_sequences=False))
model.add(Dropout(0.2))
model.add(Dense(trainY.shape[1]))

model.compile(optimizer='adam', loss='mse')
model.summary()
# Out:
# Model: "sequential_20"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_40 (LSTM)              (None, 21, 64)            28928
#
#  lstm_41 (LSTM)              (None, 32)                12416
#
#  dropout_20 (Dropout)        (None, 32)                0
#
#  dense_20 (Dense)            (None, 1)                 33
#
# =================================================================
# Total params: 41,377
# Trainable params: 41,377
# Non-trainable params: 0
# _________________________________________________________________

# %%
# fit model
history = model.fit(x=trainX, y=trainY, epochs=10, batch_size=16, validation_split=0.2, verbose=1)
# Out:
# Epoch 1/10
# 400/400 [==============================] - 8s 14ms/step - loss: 0.5519 - val_loss: nan
# Epoch 2/10
# 400/400 [==============================] - 5s 13ms/step - loss: 0.0783 - val_loss: nan
# Epoch 3/10
# 400/400 [==============================] - 5s 13ms/step - loss: 0.0569 - val_loss: nan
# Epoch 4/10
# 400/400 [==============================] - 5s 13ms/step - loss: 0.0511 - val_loss: nan
# Epoch 5/10
# 400/400 [==============================] - 5s 13ms/step - loss: 0.0448 - val_loss: nan
# Epoch 6/10
# 400/400 [==============================] - 5s 13ms/step - loss: 0.0420 - val_loss: nan
# Epoch 7/10
# 400/400 [==============================] - 5s 13ms/step - loss: 0.0396 - val_loss: nan
# Epoch 8/10
# 400/400 [==============================] - 5s 13ms/step - loss: 0.0373 - val_loss: nan
# Epoch 9/10
# 400/400 [==============================] - 5s 13ms/step - loss: 0.0387 - val_loss: nan
# Epoch 10/10
# 400/400 [==============================] - 5s 13ms/step - loss: 0.0335 - val_loss: nan

# %%
# plotting training/validation loss

plt.plot(history.history['loss'], label='Training loss')
plt.plot(history.history['val_loss'], label='Validation loss')
plt.legend()
plt.show()

# %%
# Forecasting
# start with the last day in training set and predict future
n_future = 105
forecast_period_dates = pd.date_range(list(train_dates)[-1], periods=n_future, freq='1d').tolist()

forecast = model.predict(trainX[-n_future:])
# Out:
# 4/4 [==============================] - 0s 3ms/step

# %%
# Perform inverse transformation to rescale back to original range

forecast_copies = np.repeat(forecast, df_for_training.shape[1], axis=-1)
h1_future = scaler.inverse_transform(forecast_copies)[:,0]


print(h1_future)
# Out:
# [ 18086.717   17390.002   52660.4     16192.11   127218.91   133839.17
#    4054.716    5335.677  135524.97   133797.95     5115.5127  68570.195
#   24168.72    69784.13    80995.55    17801.768   17308.326   50439.773
#   15717.407  114957.91   123403.82     3493.4426   5250.919  127017.54
#  124231.9      4681.376   68028.516   23085.014   68070.85    79516.02
#   18017.611   16982.693   50134.43    16386.701  119634.92   129181.83
#    4206.04     7536.712  130761.56   127188.63     5997.372   68797.63
#   24244.865   69301.81    80981.625   18153.506   16419.33    50494.87
#   16111.724  114050.14   120854.445    3685.759    5636.8057 124248.734
#  123795.65     5617.8135  67690.85    22937.686   68393.414   81448.17
#   18087.459   16049.821   49191.86    15539.552  117208.12   125630.19
#    3758.7083   5217.4814 126580.25   127514.766    5712.9893  67462.414
#   22072.666   70359.13    84689.46    17592.94    16633.807   52294.902
#   15779.892  130121.87   137617.36     4191.6455   6211.6377 139162.64
#  137055.16     5639.4346  68804.39    24619.725   74910.54    92783.65
#   18991.803   18053.13    52398.746   16299.548  122932.914  132861.05
#    4617.704    6398.747  132816.31   129475.13     5311.9307  69056.04
#   24128.13    70026.1     81820.34  ]

# %%
def energy_predictions(x_var_index):
    return scaler.inverse_transform(forecast_copies)[:,x_var_index].tolist()

# %%
h1 = energy_predictions(0)
h2 = energy_predictions(1)
h3 = energy_predictions(2)
h4 = energy_predictions(3)
h5 = energy_predictions(4)
h6 = energy_predictions(5)
h7 = energy_predictions(6)
h8 = energy_predictions(7)
h9 = energy_predictions(8)
h10 = energy_predictions(9)
h11 = energy_predictions(10)
h12 = energy_predictions(11)
h13 = energy_predictions(12)
h14 = energy_predictions(13)
h15 = energy_predictions(14)
h16 = energy_predictions(15)
h17 = energy_predictions(16)
h18 = energy_predictions(17)
h19 = energy_predictions(18)
h20 = energy_predictions(19)
h21 = energy_predictions(20)
h22 = energy_predictions(21)
h23 = energy_predictions(22)
h24 = energy_predictions(23)
# date = energy.loc[6881:6992,'date']



d = {'h1': h1, 'h2': h2, 'h3': h3, 'h4': h4, 'h5': h5, 'h6': h6, 'h7': h7, 'h8': h8,
    'h9': h9, 'h10': h10, 'h11': h11, 'h12': h12, 'h13': h13, 'h14': h14, 'h15': h15, 'h16': h16,
    'h17': h17, 'h18': h18, 'h19': h19, 'h20': h20, 'h21': h21, 'h22': h22, 'h23': h23, 'h24': h24}

df = pd.DataFrame(data=d)



print(df)


df.to_excel('energy_naive_predictions.xlsx')
# Out:
#                 h1             h2             h3             h4  \
# 0     18086.716797   17126.949219   16647.992188   16439.269531
# 1     17390.001953   16443.644531   15969.129883   15756.200195
# 2     52660.398438   51035.140625   50335.808594   50335.757812
# 3     16192.110352   15268.813477   14801.934570   14581.774414
# 4    127218.906250  124158.523438  122983.953125  123433.898438
# ..             ...            ...            ...            ...
# 100    5311.930664    4598.059082    4200.528320    3914.703613
# 101   69056.039062   67115.195312   66311.359375   66410.265625
# 102   24128.130859   23052.074219   22534.609375   22362.351562
# 103   70026.101562   68066.585938   67256.570312   67361.328125
# 104   81820.343750   79633.804688   78748.609375   78924.554688
#
#                 h5             h6             h7             h8  \
# 0     16648.701172   17002.140625   18651.191406   19748.337891
# 1     15946.331055   16251.902344   17822.566406   18876.767578
# 2     51503.160156   54231.835938   59770.667969   62998.898438
# 3     14738.709961   14961.988281   16397.882812   17378.244141
# 4    126667.171875  134518.078125  148445.265625  156269.203125
# ..             ...            ...            ...            ...
# 100    3770.170654    3245.968506    3457.770508    3767.489502
# 101   68031.953125   71887.023438   79270.484375   83509.328125
# 102   22739.177734   23507.667969   25836.417969   27305.951172
# 103   69009.898438   72931.609375   80424.210938   84722.843750
# 104   80899.914062   85631.906250   94451.437500   99477.054688
#
#                 h9            h10  ...            h15            h16  \
# 0     20283.035156   20630.433594  ...   19566.890625   19611.382812
# 1     19415.527344   19766.566406  ...   18721.550781   18763.906250
# 2     63332.156250   63498.953125  ...   61515.968750   61666.382812
# 3     17923.984375   18281.281250  ...   17268.121094   17306.808594
# 4    156168.046875  155945.375000  ...  151979.609375  152358.453125
# ..             ...            ...  ...            ...            ...
# 100    4376.625000    4790.754395  ...    4066.937988    4072.289795
# 101   83747.054688   83828.203125  ...   81409.203125   81609.843750
# 102   27805.449219   28121.292969  ...   26897.085938   26960.085938
# 103   84954.921875   85031.007812  ...   82586.203125   82789.820312
# 104   99640.414062   99654.890625  ...   96896.429688   97136.187500
#
#                h17            h18            h19            h20  \
# 0     20424.511719   21740.367188   22912.828125   23364.003906
# 1     19560.804688   20839.976562   21998.753906   22457.359375
# 2     63285.117188   66421.250000   68272.718750   68355.257812
# 3     18075.792969   19291.894531   20427.144531   20898.527344
# 4    155714.468750  162776.062500  166091.812500  165379.390625
# ..             ...            ...            ...            ...
# 100    4587.754883    5231.020508    6152.598633    6739.979980
# 101   83610.617188   87609.968750   89783.437500   89691.164062
# 102   27913.988281   29547.917969   30839.027344   31225.789062
# 103   84813.195312   88863.625000   91056.140625   90953.523438
# 104   99434.375000  104105.765625  106529.914062  106301.539062
#
#                h21            h22            h23            h24
# 0     23463.248047   22806.056641   21930.675781   19836.224609
# 1     22570.826172   21950.720703   21139.304688   19108.283203
# 2     67748.820312   65251.074219   61201.562500   55959.503906
# 3     21036.439453   20480.107422   19778.667969   17856.701172
# 4    163251.140625  156784.203125  145889.656250  133859.750000
# ..             ...            ...            ...            ...
# 100    7099.969727    7122.854004    7420.301270    6488.869141
# 101   88750.070312   85379.492188   79824.734375   73090.007812
# 102   31201.720703   30222.908203   28792.882812   26148.416016
# 103   89992.632812   86570.406250   80926.593750   74103.546875
# 104  105099.921875  101049.820312   94323.203125   86426.406250
#
# [105 rows x 24 columns]

# %% [markdown]
# Do the same thing to make predictions for June 20-26

# %%
merged = pd.read_excel('merged(1).xlsx', sheet_name='second_pred')
df_for_training = merged.loc[0:8025,cols].astype(float)
df_for_training.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9256 entries, 0 to 9255
# Data columns (total 48 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   h1_x    9255 non-null   float64
#  1   h2_x    9255 non-null   float64
#  2   h3_x    9255 non-null   float64
#  3   h4_x    9255 non-null   float64
#  4   h5_x    9255 non-null   float64
#  5   h6_x    9255 non-null   float64
#  6   h7_x    9255 non-null   float64
#  7   h8_x    9255 non-null   float64
#  8   h9_x    9255 non-null   float64
#  9   h10_x   9255 non-null   float64
#  10  h11_x   9255 non-null   float64
#  11  h12_x   9255 non-null   float64
#  12  h13_x   9255 non-null   float64
#  13  h14_x   9255 non-null   float64
#  14  h15_x   9255 non-null   float64
#  15  h16_x   9255 non-null   float64
#  16  h17_x   9255 non-null   float64
#  17  h18_x   9255 non-null   float64
#  18  h19_x   9255 non-null   float64
#  19  h20_x   9255 non-null   float64
#  20  h21_x   9255 non-null   float64
#  21  h22_x   9255 non-null   float64
#  22  h23_x   9255 non-null   float64
#  23  h24_x   9255 non-null   float64
#  24  h1_y    9256 non-null   float64
#  25  h2_y    9256 non-null   float64
#  26  h3_y    9256 non-null   float64
#  27  h4_y    9256 non-null   float64
#  28  h5_y    9256 non-null   float64
#  29  h6_y    9256 non-null   float64
#  30  h7_y    9256 non-null   float64
#  31  h8_y    9256 non-null   float64
#  32  h9_y    9256 non-null   float64
#  33  h10_y   9256 non-null   float64
#  34  h11_y   9256 non-null   float64
#  35  h12_y   9256 non-null   float64
#  36  h13_y   9256 non-null   float64
#  37  h14_y   9256 non-null   float64
#  38  h15_y   9256 non-null   float64
#  39  h16_y   9256 non-null   float64
#  40  h17_y   9256 non-null   float64
#  41  h18_y   9256 non-null   float64
#  42  h19_y   9256 non-null   float64
#  43  h20_y   9256 non-null   float64
#  44  h21_y   9256 non-null   float64
#  45  h22_y   9256 non-null   float64
#  46  h23_y   9256 non-null   float64
#  47  h24_y   9256 non-null   float64
# dtypes: float64(48)
# memory usage: 3.4 MB

# %%
# LTSM uses sigmoid and tanh that are sensitive to magnitude, so values need to be normalized
scaler = StandardScaler()
scaler = scaler.fit(df_for_training)
df_for_training_scaled = scaler.transform(df_for_training)

# %%
trainX = []
trainY = []


n_future = 7
n_past = 21



for i in range(n_past, len(df_for_training_scaled) - n_future + 1):
    trainX.append(df_for_training_scaled[i - n_past:i, 0:df_for_training.shape[1]])
    trainY.append(df_for_training_scaled[i + n_future - 1:i + n_future, 0])

trainX, trainY = np.array(trainX), np.array(trainY)

# %%
# define Autoencoder model

model = Sequential()
model.add(LSTM(64, activation='relu', input_shape=(trainX.shape[1], trainX.shape[2]), return_sequences=True))
model.add(LSTM(32, activation='relu', return_sequences=False))
model.add(Dropout(0.2))
model.add(Dense(trainY.shape[1]))

model.compile(optimizer='adam', loss='mse')
model.summary()
# Out:
# Model: "sequential_22"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_44 (LSTM)              (None, 21, 64)            28928
#
#  lstm_45 (LSTM)              (None, 32)                12416
#
#  dropout_22 (Dropout)        (None, 32)                0
#
#  dense_22 (Dense)            (None, 1)                 33
#
# =================================================================
# Total params: 41,377
# Trainable params: 41,377
# Non-trainable params: 0
# _________________________________________________________________

# %%
# fit model
history = model.fit(x=trainX, y=trainY, epochs=10, batch_size=16, validation_split=0.2, verbose=1)
# Out:
# Epoch 1/10
# 462/462 [==============================] - 8s 13ms/step - loss: 0.6150 - val_loss: nan
# Epoch 2/10
# 462/462 [==============================] - 6s 13ms/step - loss: 0.0921 - val_loss: nan
# Epoch 3/10
# 462/462 [==============================] - 6s 12ms/step - loss: 0.0644 - val_loss: nan
# Epoch 4/10
# 462/462 [==============================] - 6s 12ms/step - loss: 0.0591 - val_loss: nan
# Epoch 5/10
# 462/462 [==============================] - 6s 13ms/step - loss: 0.0525 - val_loss: nan
# Epoch 6/10
# 462/462 [==============================] - 6s 12ms/step - loss: 0.0505 - val_loss: nan
# Epoch 7/10
# 462/462 [==============================] - 6s 12ms/step - loss: 0.0469 - val_loss: nan
# Epoch 8/10
# 462/462 [==============================] - 6s 13ms/step - loss: 0.0472 - val_loss: nan
# Epoch 9/10
# 462/462 [==============================] - 6s 12ms/step - loss: 0.0441 - val_loss: nan
# Epoch 10/10
# 462/462 [==============================] - 6s 13ms/step - loss: 0.0445 - val_loss: nan

# %%
# Forecasting
# start with the last day in training set and predict future
n_future = 105
forecast_period_dates = pd.date_range(list(train_dates)[-1], periods=n_future, freq='1d').tolist()

forecast = model.predict(trainX[-n_future:])
# Out:
# 4/4 [==============================] - 0s 7ms/step

# %%
# Perform inverse transformation to rescale back to original range

forecast_copies = np.repeat(forecast, df_for_training.shape[1], axis=-1)
h1_future = scaler.inverse_transform(forecast_copies)[:,0]


print(h1_future)
# Out:
# [ 13372.003  140462.     146696.14     5183.8154  10212.077  151989.52
#  150649.86     2905.7024  73262.29    30528.16    95639.664  114329.78
#   16294.077   20584.98    55633.582   12184.675  119476.74   122106.445
#    6057.456   13683.683  127639.37   128939.125    3905.6125  70337.05
#   26993.863   83762.66   101835.836   15653.175   18132.973   50019.195
#   11869.019  112977.664  117021.69     4137.343    7882.4014 122038.81
#  125163.77     2660.1086  68838.76    24646.469   77480.73    95896.01
#   15074.511   18079.605   48832.71    12473.565  118036.32   123082.04
#    3997.093    6162.7256 126078.61   129216.56     2808.4211  68738.59
#   23640.844   76346.67    93724.336   14497.8545  19721.32    51592.797
#   12977.222  130090.47   136933.9      6541.253    6879.5654 135414.4
#  137150.25     3529.2805  69647.08    24587.812   72370.42    86710.51
#   14469.39    19548.918   50257.836   11944.804  125621.2    133226.12
#    5720.831    7585.374  135416.31   138627.22     3472.5813  69742.47
#   24736.379   74026.6     89521.72    14852.37    19669.324   51110.645
#   13130.683  131036.13   138497.34     5712.3467   7470.3857 139734.19
#  141660.1      3472.3157  70148.55    25521.078   76480.086   91349.59
#   14426.409   19856.988   51347.867 ]

# %%
def energy_predictions(x_var_index):
    return scaler.inverse_transform(forecast_copies)[:,x_var_index].tolist()

# %%
h1 = energy_predictions(0)
h2 = energy_predictions(1)
h3 = energy_predictions(2)
h4 = energy_predictions(3)
h5 = energy_predictions(4)
h6 = energy_predictions(5)
h7 = energy_predictions(6)
h8 = energy_predictions(7)
h9 = energy_predictions(8)
h10 = energy_predictions(9)
h11 = energy_predictions(10)
h12 = energy_predictions(11)
h13 = energy_predictions(12)
h14 = energy_predictions(13)
h15 = energy_predictions(14)
h16 = energy_predictions(15)
h17 = energy_predictions(16)
h18 = energy_predictions(17)
h19 = energy_predictions(18)
h20 = energy_predictions(19)
h21 = energy_predictions(20)
h22 = energy_predictions(21)
h23 = energy_predictions(22)
h24 = energy_predictions(23)
# date = energy.loc[6881:6992,'date']



d = {'h1': h1, 'h2': h2, 'h3': h3, 'h4': h4, 'h5': h5, 'h6': h6, 'h7': h7, 'h8': h8,
    'h9': h9, 'h10': h10, 'h11': h11, 'h12': h12, 'h13': h13, 'h14': h14, 'h15': h15, 'h16': h16,
    'h17': h17, 'h18': h18, 'h19': h19, 'h20': h20, 'h21': h21, 'h22': h22, 'h23': h23, 'h24': h24}

df = pd.DataFrame(data=d)



print(df)


df.to_excel('energy_naive_predictions3.xlsx')
# Out:
#                 h1             h2             h3             h4  \
# 0     13372.002930   12497.248047   12037.326172   11787.963867
# 1    140462.000000  136242.000000  134292.703125  134322.765625
# 2    146696.140625  142312.031250  140289.687500  140333.468750
# 3      5183.815430    4524.587402    4160.623047    3893.256836
# 4     10212.077148    9420.498047    8997.607422    8741.295898
# ..             ...            ...            ...            ...
# 100   76480.085938   73944.203125   72744.718750   72634.109375
# 101   91349.593750   88422.312500   87048.578125   86970.656250
# 102   14426.409180   13523.900391   13051.623047   12804.577148
# 103   19856.988281   18811.533203   18275.615234   18040.511719
# 104   51347.867188   49473.511719   48568.554688   48402.683594
#
#                 h5             h6             h7             h8  \
# 0     11836.435547   11958.087891   13073.603516   13919.613281
# 1    137364.046875  145685.656250  160529.187500  169646.062500
# 2    143521.546875  152245.375000  167762.328125  177284.906250
# 3      3748.907959    3342.256104    3573.294678    3886.426025
# 4      8715.357422    8633.130859    9407.318359   10047.675781
# ..             ...            ...            ...            ...
# 100   74168.695312   78362.132812   86294.460938   91247.468750
# 101   88855.398438   94008.234375  103546.742188  109467.437500
# 102   12877.880859   13067.564453   14296.974609   15211.601562
# 103   18241.697266   18781.767578   20597.775391   21865.816406
# 104   49345.441406   51917.328125   57134.925781   60452.359375
#
#                 h9            h10  ...            h15            h16  \
# 0     14534.958008   14919.666016  ...   13523.900391   13381.384766
# 1    170958.031250  172615.687500  ...  175585.859375  176154.531250
# 2    178631.046875  180351.140625  ...  183535.484375  184139.031250
# 3      4456.887695    4759.587891  ...    3082.533203    2894.189941
# 4     10645.700195   10998.759766  ...    9494.447266    9334.244141
# ..             ...            ...  ...            ...            ...
# 100   92208.734375   93225.531250  ...   93997.726562   94208.359375
# 101  110510.203125  111675.937500  ...  112958.953125  113252.789062
# 102   15832.727539   16227.994141  ...   14868.455078   14731.837891
# 103   22516.710938   22966.373047  ...   21793.388672   21687.158203
# 104   61275.859375   62040.937500  ...   61949.761719   62019.753906
#
#                h17            h18            h19            h20  \
# 0     14041.510742   15216.197266   16494.119141   17118.548828
# 1    179223.796875  185155.250000  187317.437500  185522.484375
# 2    187326.468750  193491.265625  195696.828125  193783.203125
# 3      3399.096436    4267.322754    5488.268555    6268.571777
# 4      9934.471680   10990.892578   12246.823242   12931.407227
# ..             ...            ...            ...            ...
# 100   96064.773438   99601.492188  101318.507812  100741.562500
# 101  115391.070312  119484.335938  121304.812500  120444.796875
# 102   15411.948242   16626.103516   17911.361328   18515.712891
# 103   22470.212891   23887.630859   25210.669922   25711.642578
# 104   63399.757812   65995.820312   67537.968750   67439.460938
#
#                h21            h22            h23            h24
# 0     17478.849609   17167.968750   16609.984375   14902.797852
# 1    183501.515625  176468.031250  163242.156250  148946.593750
# 2    191645.421875  184282.171875  170434.890625  155521.843750
# 3      6782.295410    6904.546875    7162.726074    6266.590332
# 4     13350.920898   13207.187500   12964.170898   11569.977539
# ..             ...            ...            ...            ...
# 100   99919.421875   96270.343750   89421.960938   81463.867188
# 101  119344.046875  114908.421875  106577.898438   97146.968750
# 102   18856.263672   18489.609375   17826.523438   16014.899414
# 103   25950.439453   25296.527344   24092.140625   21742.609375
# 104   67088.218750   64768.546875   60425.257812   54956.531250
#
# [105 rows x 24 columns]

# %% [markdown]
# ### After adding in these predictions into the merged(1).xlsx file, perform the same process to get the predictions for September 10-16, 2016

# %%
merged = pd.read_excel('merged(1).xlsx', sheet_name='third_pred')
df_for_training = merged.loc[0:9255,cols].astype(float)
df_for_training.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9256 entries, 0 to 9255
# Data columns (total 48 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   h1_x    9255 non-null   float64
#  1   h2_x    9255 non-null   float64
#  2   h3_x    9255 non-null   float64
#  3   h4_x    9255 non-null   float64
#  4   h5_x    9255 non-null   float64
#  5   h6_x    9255 non-null   float64
#  6   h7_x    9255 non-null   float64
#  7   h8_x    9255 non-null   float64
#  8   h9_x    9255 non-null   float64
#  9   h10_x   9255 non-null   float64
#  10  h11_x   9255 non-null   float64
#  11  h12_x   9255 non-null   float64
#  12  h13_x   9255 non-null   float64
#  13  h14_x   9255 non-null   float64
#  14  h15_x   9255 non-null   float64
#  15  h16_x   9255 non-null   float64
#  16  h17_x   9255 non-null   float64
#  17  h18_x   9255 non-null   float64
#  18  h19_x   9255 non-null   float64
#  19  h20_x   9255 non-null   float64
#  20  h21_x   9255 non-null   float64
#  21  h22_x   9255 non-null   float64
#  22  h23_x   9255 non-null   float64
#  23  h24_x   9255 non-null   float64
#  24  h1_y    9256 non-null   float64
#  25  h2_y    9256 non-null   float64
#  26  h3_y    9256 non-null   float64
#  27  h4_y    9256 non-null   float64
#  28  h5_y    9256 non-null   float64
#  29  h6_y    9256 non-null   float64
#  30  h7_y    9256 non-null   float64
#  31  h8_y    9256 non-null   float64
#  32  h9_y    9256 non-null   float64
#  33  h10_y   9256 non-null   float64
#  34  h11_y   9256 non-null   float64
#  35  h12_y   9256 non-null   float64
#  36  h13_y   9256 non-null   float64
#  37  h14_y   9256 non-null   float64
#  38  h15_y   9256 non-null   float64
#  39  h16_y   9256 non-null   float64
#  40  h17_y   9256 non-null   float64
#  41  h18_y   9256 non-null   float64
#  42  h19_y   9256 non-null   float64
#  43  h20_y   9256 non-null   float64
#  44  h21_y   9256 non-null   float64
#  45  h22_y   9256 non-null   float64
#  46  h23_y   9256 non-null   float64
#  47  h24_y   9256 non-null   float64
# dtypes: float64(48)
# memory usage: 3.4 MB

# %%
# LTSM uses sigmoid and tanh that are sensitive to magnitude, so values need to be normalized
scaler = StandardScaler()
scaler = scaler.fit(df_for_training)
df_for_training_scaled = scaler.transform(df_for_training)

# %%
trainX = []
trainY = []


n_future = 7
n_past = 21



for i in range(n_past, len(df_for_training_scaled) - n_future + 1):
    trainX.append(df_for_training_scaled[i - n_past:i, 0:df_for_training.shape[1]])
    trainY.append(df_for_training_scaled[i + n_future - 1:i + n_future, 0])

trainX, trainY = np.array(trainX), np.array(trainY)

# %%
# define Autoencoder model

model = Sequential()
model.add(LSTM(64, activation='relu', input_shape=(trainX.shape[1], trainX.shape[2]), return_sequences=True))
model.add(LSTM(32, activation='relu', return_sequences=False))
model.add(Dropout(0.2))
model.add(Dense(trainY.shape[1]))

model.compile(optimizer='adam', loss='mse')
model.summary()
# Out:
# Model: "sequential_24"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_48 (LSTM)              (None, 21, 64)            28928
#
#  lstm_49 (LSTM)              (None, 32)                12416
#
#  dropout_24 (Dropout)        (None, 32)                0
#
#  dense_24 (Dense)            (None, 1)                 33
#
# =================================================================
# Total params: 41,377
# Trainable params: 41,377
# Non-trainable params: 0
# _________________________________________________________________

# %%
# fit model
history = model.fit(x=trainX, y=trainY, epochs=10, batch_size=16, validation_split=0.2, verbose=1)
# Out:
# Epoch 1/10
# 462/462 [==============================] - 8s 13ms/step - loss: 0.6471 - val_loss: nan
# Epoch 2/10
# 462/462 [==============================] - 6s 13ms/step - loss: 0.0825 - val_loss: nan
# Epoch 3/10
# 462/462 [==============================] - 6s 12ms/step - loss: 0.0609 - val_loss: nan
# Epoch 4/10
# 462/462 [==============================] - 6s 13ms/step - loss: 0.0545 - val_loss: nan
# Epoch 5/10
# 462/462 [==============================] - 6s 13ms/step - loss: 0.0504 - val_loss: nan
# Epoch 6/10
# 462/462 [==============================] - 6s 12ms/step - loss: 0.0495 - val_loss: nan
# Epoch 7/10
# 462/462 [==============================] - 6s 13ms/step - loss: 0.0454 - val_loss: nan
# Epoch 8/10
# 462/462 [==============================] - 6s 12ms/step - loss: 0.0455 - val_loss: nan
# Epoch 9/10
# 462/462 [==============================] - 6s 12ms/step - loss: 0.0441 - val_loss: nan
# Epoch 10/10
# 462/462 [==============================] - 6s 13ms/step - loss: 0.0433 - val_loss: nan

# %%
# plotting training/validation loss

plt.plot(history.history['loss'], label='Training loss')
plt.plot(history.history['val_loss'], label='Validation loss')
plt.legend()
plt.show()

# %%
# Forecasting
# start with the last day in training set and predict future
n_future = 105
forecast_period_dates = pd.date_range(list(train_dates)[-1], periods=n_future, freq='1d').tolist()

forecast = model.predict(trainX[-n_future:])
# Out:
# 4/4 [==============================] - 0s 5ms/step

# %%
# Perform inverse transformation to rescale back to original range

forecast_copies = np.repeat(forecast, df_for_training.shape[1], axis=-1)
h1_future = scaler.inverse_transform(forecast_copies)[:,0]


print(h1_future)
# Out:
# [ 16112.624  140199.08   147926.7       278.7336   9449.597  148520.6
#  150760.95     5084.374   72998.4     26479.191   94044.27   108265.63
#   16539.004   15975.249   53899.76    15305.757  118387.875  126348.84
#    3354.011   10365.417  124615.73   128854.89     6850.6045  70381.29
#   22317.242   79863.19    95128.516   15362.608   13461.687   49527.387
#   14540.526  114082.36   121411.59     2778.2375   9121.14   121222.81
#  125819.8      5327.2686  68767.336   20136.012   73482.164   87721.26
#   13867.843   12710.327   48362.06    13597.667  120921.93   128542.6
#    1287.3118   7301.9365 124946.69   130553.79     5351.366   68602.03
#   20190.59    72833.09    86127.98    13004.937   13445.464   51668.367
#   14990.987  134156.23   141572.44     1513.2883   7391.421  134992.94
#  140139.27     6218.995   69052.06    19037.535   70441.49    80276.26
#   12823.163   13512.839   50612.45    14332.444  130788.59   139938.88
#    1193.6946   7722.507  137453.89   144088.56     6139.464   69528.31
#   19877.734   72108.23    81978.305   12822.948   13899.1045  51303.504
#   14506.7295 134473.6    143337.92     1175.5461   8739.315  141276.45
#  147392.9      6205.874   70206.39    20636.531   75659.23    86147.48
#   13179.991   14212.12    52151.74  ]

# %%
def energy_predictions(x_var_index):
    return scaler.inverse_transform(forecast_copies)[:,x_var_index].tolist()

# %%
h1 = energy_predictions(0)
h2 = energy_predictions(1)
h3 = energy_predictions(2)
h4 = energy_predictions(3)
h5 = energy_predictions(4)
h6 = energy_predictions(5)
h7 = energy_predictions(6)
h8 = energy_predictions(7)
h9 = energy_predictions(8)
h10 = energy_predictions(9)
h11 = energy_predictions(10)
h12 = energy_predictions(11)
h13 = energy_predictions(12)
h14 = energy_predictions(13)
h15 = energy_predictions(14)
h16 = energy_predictions(15)
h17 = energy_predictions(16)
h18 = energy_predictions(17)
h19 = energy_predictions(18)
h20 = energy_predictions(19)
h21 = energy_predictions(20)
h22 = energy_predictions(21)
h23 = energy_predictions(22)
h24 = energy_predictions(23)
# date = energy.loc[6881:6992,'date']



d = {'h1': h1, 'h2': h2, 'h3': h3, 'h4': h4, 'h5': h5, 'h6': h6, 'h7': h7, 'h8': h8,
    'h9': h9, 'h10': h10, 'h11': h11, 'h12': h12, 'h13': h13, 'h14': h14, 'h15': h15, 'h16': h16,
    'h17': h17, 'h18': h18, 'h19': h19, 'h20': h20, 'h21': h21, 'h22': h22, 'h23': h23, 'h24': h24}

df = pd.DataFrame(data=d)



print(df)


df.to_excel('energy_naive_predictions3(1).xlsx')
# Out:
#                 h1             h2             h3             h4  \
# 0     16112.624023   15165.732422   14673.693359   14430.354492
# 1    140199.078125  135986.000000  134039.781250  134069.265625
# 2    147926.703125  143510.203125  141473.437500  141519.906250
# 3       278.733612    -251.377396    -557.861511    -836.012695
# 4      9449.596680    8678.087891    8264.130859    8006.143555
# ..             ...            ...            ...            ...
# 100   75659.226562   73144.945312   71955.085938   71842.671875
# 101   86147.476562   83357.125000   82044.351562   81954.992188
# 102   13179.991211   12310.291016   11852.619141   11602.831055
# 103   14212.120117   13315.251953   12845.486328   12597.967773
# 104   52151.738281   50256.222656   49341.843750   49177.742188
#
#                 h5             h6             h7             h8  \
# 0     14543.365234   14841.845703   16253.396484   17277.761719
# 1    137104.359375  145409.000000  160224.140625  169323.906250
# 2    144736.968750  153540.203125  169190.078125  178792.734375
# 3     -1095.869507   -1819.001709   -2117.799072   -2123.886475
# 4      7962.251465    7830.826172    8522.646484    9113.394531
# ..             ...            ...            ...            ...
# 100   73357.929688   77498.406250   85342.070312   90241.656250
# 101   83717.234375   88534.421875   97511.007812  103093.156250
# 102   11646.783203   11756.048828   12850.822266   13684.332031
# 103   12666.224609   12842.083984   14048.345703   14949.027344
# 104   50139.429688   52763.183594   58067.613281   61437.359375
#
#                 h9            h10  ...            h15            h16  \
# 0     17908.128906   18320.287109  ...   17018.673828   16891.490234
# 1    170634.437500  172289.453125  ...  175250.593750  175817.781250
# 2    180145.625000  181878.031250  ...  185104.656250  185715.093750
# 3     -1580.307739   -1326.739990  ...   -3172.302734   -3388.091309
# 4      9707.239258   10052.658203  ...    8522.150391    8357.681641
# ..             ...            ...  ...            ...            ...
# 100   91198.414062   92207.000000  ...   92950.992188   93157.031250
# 101  104107.406250  105221.039062  ...  106325.343750  106590.070312
# 102   14298.622070   14681.408203  ...   13279.056641   13135.455078
# 103   15568.977539   15962.103516  ...   14595.197266   14457.376953
# 104   62265.269531   63038.398438  ...   62974.839844   63049.328125
#
#                h17            h18            h19            h20  \
# 0     17603.564453   18880.837891   20177.822266   20750.080078
# 1    178882.062500  184803.687500  186964.046875  185174.093750
# 2    188925.859375  195136.703125  197350.843750  195413.781250
# 3     -2976.161377   -2291.528809   -1104.708252    -231.029953
# 4      8943.448242    9971.337891   11221.963867   11921.055664
# ..             ...            ...            ...            ...
# 100   94997.882812   98503.882812  100215.187500   99653.867188
# 101  108629.742188  112528.296875  114312.578125  113551.593750
# 102   13791.940430   14959.447266   16236.034180   16864.111328
# 103   15133.432617   16339.564453   17623.330078   18231.767578
# 104   64444.570312   67070.718750   68618.460938   68504.648438
#
#                h21            h22            h23            h24
# 0     21059.029297   20603.183594   19772.019531   17793.375000
# 1    183158.062500  176138.468750  162938.796875  148669.281250
# 2    193252.937500  185824.593750  171854.671875  156819.718750
# 3       374.600189     756.312561    1503.413330    1093.125488
# 4     12354.858398   12251.460938   12084.444336   10765.774414
# ..             ...            ...            ...            ...
# 100   98847.101562   95241.445312   88474.890625   80598.093750
# 101  112548.312500  108387.859375  100575.875000   91660.210938
# 102   17228.013672   16927.296875   16388.445312   14700.278320
# 103   18576.326172   18221.007812   17579.285156   15788.883789
# 104   68138.343750   65776.148438   61352.738281   55804.382812
#
# [105 rows x 24 columns]

# %% [markdown]
# ### After adding in these predictions into the merged(1).xlsx file, perform the same process to get the predictions for December 25-31, 2016

# %%
merged = pd.read_excel('merged(1).xlsx', sheet_name='fourth_pred')
df_for_training = merged.loc[0:10845,cols].astype(float)
df_for_training.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10846 entries, 0 to 10845
# Data columns (total 48 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   h1_x    10845 non-null  float64
#  1   h2_x    10845 non-null  float64
#  2   h3_x    10845 non-null  float64
#  3   h4_x    10845 non-null  float64
#  4   h5_x    10845 non-null  float64
#  5   h6_x    10845 non-null  float64
#  6   h7_x    10845 non-null  float64
#  7   h8_x    10845 non-null  float64
#  8   h9_x    10845 non-null  float64
#  9   h10_x   10845 non-null  float64
#  10  h11_x   10845 non-null  float64
#  11  h12_x   10845 non-null  float64
#  12  h13_x   10845 non-null  float64
#  13  h14_x   10845 non-null  float64
#  14  h15_x   10845 non-null  float64
#  15  h16_x   10845 non-null  float64
#  16  h17_x   10845 non-null  float64
#  17  h18_x   10845 non-null  float64
#  18  h19_x   10845 non-null  float64
#  19  h20_x   10845 non-null  float64
#  20  h21_x   10845 non-null  float64
#  21  h22_x   10845 non-null  float64
#  22  h23_x   10845 non-null  float64
#  23  h24_x   10845 non-null  float64
#  24  h1_y    10846 non-null  float64
#  25  h2_y    10846 non-null  float64
#  26  h3_y    10846 non-null  float64
#  27  h4_y    10846 non-null  float64
#  28  h5_y    10846 non-null  float64
#  29  h6_y    10846 non-null  float64
#  30  h7_y    10846 non-null  float64
#  31  h8_y    10846 non-null  float64
#  32  h9_y    10846 non-null  float64
#  33  h10_y   10846 non-null  float64
#  34  h11_y   10846 non-null  float64
#  35  h12_y   10846 non-null  float64
#  36  h13_y   10846 non-null  float64
#  37  h14_y   10846 non-null  float64
#  38  h15_y   10846 non-null  float64
#  39  h16_y   10846 non-null  float64
#  40  h17_y   10846 non-null  float64
#  41  h18_y   10846 non-null  float64
#  42  h19_y   10846 non-null  float64
#  43  h20_y   10846 non-null  float64
#  44  h21_y   10846 non-null  float64
#  45  h22_y   10846 non-null  float64
#  46  h23_y   10846 non-null  float64
#  47  h24_y   10846 non-null  float64
# dtypes: float64(48)
# memory usage: 4.0 MB

# %%
# LTSM uses sigmoid and tanh that are sensitive to magnitude, so values need to be normalized
scaler = StandardScaler()
scaler = scaler.fit(df_for_training)
df_for_training_scaled = scaler.transform(df_for_training)

# %%
trainX = []
trainY = []


n_future = 7
n_past = 21



for i in range(n_past, len(df_for_training_scaled) - n_future + 1):
    trainX.append(df_for_training_scaled[i - n_past:i, 0:df_for_training.shape[1]])
    trainY.append(df_for_training_scaled[i + n_future - 1:i + n_future, 0])

trainX, trainY = np.array(trainX), np.array(trainY)

# %%
# define Autoencoder model

model = Sequential()
model.add(LSTM(64, activation='relu', input_shape=(trainX.shape[1], trainX.shape[2]), return_sequences=True))
model.add(LSTM(32, activation='relu', return_sequences=False))
model.add(Dropout(0.2))
model.add(Dense(trainY.shape[1]))

model.compile(optimizer='adam', loss='mse')
model.summary()
# Out:
# Model: "sequential_25"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_50 (LSTM)              (None, 21, 64)            28928
#
#  lstm_51 (LSTM)              (None, 32)                12416
#
#  dropout_25 (Dropout)        (None, 32)                0
#
#  dense_25 (Dense)            (None, 1)                 33
#
# =================================================================
# Total params: 41,377
# Trainable params: 41,377
# Non-trainable params: 0
# _________________________________________________________________

# %%
# fit model
history = model.fit(x=trainX, y=trainY, epochs=10, batch_size=16, validation_split=0.2, verbose=1)
# Out:
# Epoch 1/10
# 541/541 [==============================] - 9s 13ms/step - loss: 0.5721 - val_loss: nan
# Epoch 2/10
# 541/541 [==============================] - 7s 12ms/step - loss: 0.0966 - val_loss: nan
# Epoch 3/10
# 541/541 [==============================] - 7s 13ms/step - loss: 0.0706 - val_loss: nan
# Epoch 4/10
# 541/541 [==============================] - 7s 12ms/step - loss: 0.0586 - val_loss: nan
# Epoch 5/10
# 541/541 [==============================] - 7s 13ms/step - loss: 0.0546 - val_loss: nan
# Epoch 6/10
# 541/541 [==============================] - 7s 12ms/step - loss: 0.0519 - val_loss: nan
# Epoch 7/10
# 541/541 [==============================] - 7s 13ms/step - loss: 0.0520 - val_loss: nan
# Epoch 8/10
# 541/541 [==============================] - 7s 13ms/step - loss: 0.0491 - val_loss: nan
# Epoch 9/10
# 541/541 [==============================] - 7s 13ms/step - loss: 0.0452 - val_loss: nan
# Epoch 10/10
# 541/541 [==============================] - 7s 13ms/step - loss: 0.0429 - val_loss: nan

# %%
# Forecasting
# start with the last day in training set and predict future
n_future = 105
forecast_period_dates = pd.date_range(list(train_dates)[-1], periods=n_future, freq='1d').tolist()

forecast = model.predict(trainX[-n_future:])
# Out:
# 4/4 [==============================] - 0s 6ms/step

# %%
# Perform inverse transformation to rescale back to original range

forecast_copies = np.repeat(forecast, df_for_training.shape[1], axis=-1)
h1_future = scaler.inverse_transform(forecast_copies)[:,0]


print(h1_future)
# Out:
# [ 23286.227  170499.08   175836.88     2448.1091   9450.223  187761.72
#  179550.53     7850.6406  77115.88    29452.352  112020.96   137376.33
#   22313.746   23245.79    68271.875   23774.168  169268.56   173099.7
#    2829.0193  14106.254  185455.42   180030.75     5643.215   75464.26
#   29117.223  119543.44   148746.      24597.559   25306.914   77210.81
#   28995.328  196869.61   201470.34     5113.0195  13468.941  213191.88
#  200288.8      8752.707   78759.51    32332.523  133064.17   161846.61
#   25006.86    27607.344   79525.62    29957.21   197080.45   200670.4
#    4885.949   14804.195  214758.73   200602.92     9142.109   79855.35
#   33322.957  134412.69   163284.31    24615.93    28017.41    78283.15
#   31177.316  194567.67   198905.4      4810.004   14377.414  211406.75
#  196798.73     9204.559   81306.26    34698.73   132675.56   159788.16
#   23980.477   27422.082   73516.31    28063.844  179678.88   183296.53
#    3767.2732  13763.359  192153.72   181760.52     6506.7617  83555.4
#   37657.742  119428.46   145083.02    24217.285   24201.016   65524.09
#   29091.594  146806.4    147653.48     2725.4998  14296.828  149577.64
#  149174.11     3537.0623  79881.39    32455.832   98170.85   123251.04
#   22262.414   19990.215   56302.75  ]

# %%
def energy_predictions(x_var_index):
    return scaler.inverse_transform(forecast_copies)[:,x_var_index].tolist()

# %%
h1 = energy_predictions(0)
h2 = energy_predictions(1)
h3 = energy_predictions(2)
h4 = energy_predictions(3)
h5 = energy_predictions(4)
h6 = energy_predictions(5)
h7 = energy_predictions(6)
h8 = energy_predictions(7)
h9 = energy_predictions(8)
h10 = energy_predictions(9)
h11 = energy_predictions(10)
h12 = energy_predictions(11)
h13 = energy_predictions(12)
h14 = energy_predictions(13)
h15 = energy_predictions(14)
h16 = energy_predictions(15)
h17 = energy_predictions(16)
h18 = energy_predictions(17)
h19 = energy_predictions(18)
h20 = energy_predictions(19)
h21 = energy_predictions(20)
h22 = energy_predictions(21)
h23 = energy_predictions(22)
h24 = energy_predictions(23)
# date = energy.loc[6881:6992,'date']



d = {'h1': h1, 'h2': h2, 'h3': h3, 'h4': h4, 'h5': h5, 'h6': h6, 'h7': h7, 'h8': h8,
    'h9': h9, 'h10': h10, 'h11': h11, 'h12': h12, 'h13': h13, 'h14': h14, 'h15': h15, 'h16': h16,
    'h17': h17, 'h18': h18, 'h19': h19, 'h20': h20, 'h21': h21, 'h22': h22, 'h23': h23, 'h24': h24}

df = pd.DataFrame(data=d)



print(df)


df.to_excel('energy_naive_predictions4.xlsx')
# Out:
#                 h1             h2             h3             h4  \
# 0     23286.226562   22175.562500   21617.800781   21411.363281
# 1    170499.078125  165591.046875  163420.718750  163625.593750
# 2    175836.875000  170791.156250  168562.359375  168782.156250
# 3      2448.109131    1874.961670    1545.461304    1280.805542
# 4      9450.222656    8696.458008    8290.257812    8045.161133
# ..             ...            ...            ...            ...
# 100   98170.851562   95128.531250   93750.484375   93753.281250
# 101  123251.039062  119561.781250  117909.000000  117981.867188
# 102   22262.414062   21178.156250   20631.609375   20422.312500
# 103   19990.214844   18964.570312   18442.914062   18227.265625
# 104   56302.750000   54340.421875   53420.996094   53306.812500
#
#                 h5             h6             h7             h8  \
# 0     21717.759766   22591.378906   24841.935547   26288.501953
# 1    167408.468750  177702.812500  195946.703125  206926.609375
# 2    172691.093750  183327.000000  202150.812500  213476.375000
# 3      1095.095093     635.207581     621.892334     719.010376
# 4      8024.810059    8013.016113    8760.416016    9310.979492
# ..             ...            ...            ...            ...
# 100   95828.101562  101493.875000  111879.960938  118175.968750
# 101  120648.968750  127919.718750  141030.546875  148950.718750
# 102   20704.529297   21512.632812   23651.958984   25032.224609
# 103   18455.822266   19118.519531   21010.994141   22244.115234
# 104   54392.902344   57379.375000   63216.875000   66801.554688
#
#                 h9            h10  ...            h15            h16  \
# 0     26873.625000   27306.623047  ...   26118.802734   26071.751953
# 1    208064.515625  209478.671875  ...  211313.843750  212042.968750
# 2    214634.328125  216084.062500  ...  218028.859375  218786.109375
# 3      1225.878174    1519.993896  ...     -95.733002    -252.658585
# 4      9844.143555   10184.931641  ...    8712.985352    8592.982422
# ..             ...            ...  ...            ...            ...
# 100  119042.289062  119974.382812  ...  120324.312500  120672.085938
# 101  149911.203125  151010.453125  ...  151875.406250  152355.406250
# 102   25613.503906   26039.677734  ...   24830.833984   24778.384766
# 103   22816.863281   23227.892578  ...   21972.388672   21907.958984
# 104   67510.656250   68163.703125  ...   67653.875000   67780.898438
#
#                h17            h18            h19            h20  \
# 0     26961.763672   28539.673828   29817.291016   30311.496094
# 1    216038.265625  223888.859375  226542.687500  224676.375000
# 2    222894.000000  230972.046875  233675.765625  231723.875000
# 3       197.803375     887.802124    1970.615845    2798.957764
# 4      9191.147461   10179.504883   11327.780273   12043.840820
# ..             ...            ...            ...            ...
# 100  123141.703125  127910.421875  129888.093750  129181.546875
# 101  155354.078125  161191.437500  163403.578125  162294.875000
# 102   25646.802734   27181.083984   28449.130859   28959.753906
# 103   22728.447266   24165.912109   25412.716797   25959.773438
# 104   69367.359375   72352.093750   73938.359375   73903.156250
#
#                h21            h22            h23            h24
# 0     30483.417969   29603.277344   27965.587891   25311.306641
# 1    221955.125000  213182.187500  197271.375000  180471.656250
# 2    228897.718750  219838.593750  203410.250000  186097.625000
# 3      3380.415039    3617.503662    4000.192627    3348.208984
# 4     12487.680664   12349.355469   12053.145508   10728.345703
# ..             ...            ...            ...            ...
# 100  127881.757812  122986.687500  114088.507812  104238.687500
# 101  160502.187500  154262.453125  142932.593750  130672.867188
# 102   29151.796875   28326.550781   26788.123047   24232.220703
# 103   26196.472656   25493.050781   24174.923828   21837.353516
# 104   73426.203125   70775.890625   65937.054688   60110.277344
#
# [105 rows x 24 columns]

# %% [markdown]
# ### After adding in these predictions into the merged(1).xlsx file, perform the same process to get the predictions for February 13-19, 2017

# %%
merged = pd.read_excel('merged(1).xlsx', sheet_name='fifth_pred')
df_for_training = merged.loc[0:11595,cols].astype(float)
# df_for_training.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11596 entries, 0 to 11595
# Data columns (total 48 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   h1_x    11595 non-null  float64
#  1   h2_x    11595 non-null  float64
#  2   h3_x    11595 non-null  float64
#  3   h4_x    11595 non-null  float64
#  4   h5_x    11595 non-null  float64
#  5   h6_x    11595 non-null  float64
#  6   h7_x    11595 non-null  float64
#  7   h8_x    11595 non-null  float64
#  8   h9_x    11595 non-null  float64
#  9   h10_x   11595 non-null  float64
#  10  h11_x   11595 non-null  float64
#  11  h12_x   11595 non-null  float64
#  12  h13_x   11595 non-null  float64
#  13  h14_x   11595 non-null  float64
#  14  h15_x   11595 non-null  float64
#  15  h16_x   11595 non-null  float64
#  16  h17_x   11595 non-null  float64
#  17  h18_x   11595 non-null  float64
#  18  h19_x   11595 non-null  float64
#  19  h20_x   11595 non-null  float64
#  20  h21_x   11595 non-null  float64
#  21  h22_x   11595 non-null  float64
#  22  h23_x   11595 non-null  float64
#  23  h24_x   11595 non-null  float64
#  24  h1_y    11596 non-null  float64
#  25  h2_y    11596 non-null  float64
#  26  h3_y    11596 non-null  float64
#  27  h4_y    11596 non-null  float64
#  28  h5_y    11596 non-null  float64
#  29  h6_y    11596 non-null  float64
#  30  h7_y    11596 non-null  float64
#  31  h8_y    11596 non-null  float64
#  32  h9_y    11596 non-null  float64
#  33  h10_y   11596 non-null  float64
#  34  h11_y   11596 non-null  float64
#  35  h12_y   11596 non-null  float64
#  36  h13_y   11596 non-null  float64
#  37  h14_y   11596 non-null  float64
#  38  h15_y   11596 non-null  float64
#  39  h16_y   11596 non-null  float64
#  40  h17_y   11596 non-null  float64
#  41  h18_y   11596 non-null  float64
#  42  h19_y   11596 non-null  float64
#  43  h20_y   11596 non-null  float64
#  44  h21_y   11596 non-null  float64
#  45  h22_y   11596 non-null  float64
#  46  h23_y   11596 non-null  float64
#  47  h24_y   11596 non-null  float64
# dtypes: float64(48)
# memory usage: 4.2 MB

# %%
# LTSM uses sigmoid and tanh that are sensitive to magnitude, so values need to be normalized
scaler = StandardScaler()
scaler = scaler.fit(df_for_training)
df_for_training_scaled = scaler.transform(df_for_training)

# %%
trainX = []
trainY = []


n_future = 7
n_past = 21



for i in range(n_past, len(df_for_training_scaled) - n_future + 1):
    trainX.append(df_for_training_scaled[i - n_past:i, 0:df_for_training.shape[1]])
    trainY.append(df_for_training_scaled[i + n_future - 1:i + n_future, 0])

trainX, trainY = np.array(trainX), np.array(trainY)

# %%
# define Autoencoder model

model = Sequential()
model.add(LSTM(64, activation='relu', input_shape=(trainX.shape[1], trainX.shape[2]), return_sequences=True))
model.add(LSTM(32, activation='relu', return_sequences=False))
model.add(Dropout(0.2))
model.add(Dense(trainY.shape[1]))

model.compile(optimizer='adam', loss='mse')
model.summary()
# Out:
# Model: "sequential_26"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_52 (LSTM)              (None, 21, 64)            28928
#
#  lstm_53 (LSTM)              (None, 32)                12416
#
#  dropout_26 (Dropout)        (None, 32)                0
#
#  dense_26 (Dense)            (None, 1)                 33
#
# =================================================================
# Total params: 41,377
# Trainable params: 41,377
# Non-trainable params: 0
# _________________________________________________________________

# %%
# fit model
history = model.fit(x=trainX, y=trainY, epochs=10, batch_size=16, validation_split=0.2, verbose=1)
# Out:
# Epoch 1/10
# 579/579 [==============================] - 10s 13ms/step - loss: 0.4536 - val_loss: nan
# Epoch 2/10
# 579/579 [==============================] - 8s 13ms/step - loss: 0.0737 - val_loss: nan
# Epoch 3/10
# 579/579 [==============================] - 7s 13ms/step - loss: 0.0591 - val_loss: nan
# Epoch 4/10
# 579/579 [==============================] - 8s 13ms/step - loss: 0.0531 - val_loss: nan
# Epoch 5/10
# 579/579 [==============================] - 7s 13ms/step - loss: 0.0502 - val_loss: nan
# Epoch 6/10
# 579/579 [==============================] - 8s 13ms/step - loss: 0.0487 - val_loss: nan
# Epoch 7/10
# 579/579 [==============================] - 8s 13ms/step - loss: 0.0452 - val_loss: nan
# Epoch 8/10
# 579/579 [==============================] - 7s 13ms/step - loss: 0.0450 - val_loss: nan
# Epoch 9/10
# 579/579 [==============================] - 7s 13ms/step - loss: 0.0432 - val_loss: nan
# Epoch 10/10
# 579/579 [==============================] - 7s 13ms/step - loss: 0.0410 - val_loss: nan

# %%
# Forecasting
# start with the last day in training set and predict future
n_future = 105
forecast_period_dates = pd.date_range(list(train_dates)[-1], periods=n_future, freq='1d').tolist()

forecast = model.predict(trainX[-n_future:])
# Out:
# 4/4 [==============================] - 0s 6ms/step

# %%
# Perform inverse transformation to rescale back to original range

forecast_copies = np.repeat(forecast, df_for_training.shape[1], axis=-1)
h1_future = scaler.inverse_transform(forecast_copies)[:,0]


print(h1_future)
# Out:
# [ 16747.648  172108.6    178168.39     3577.2144   7062.316  175043.31
#  179275.73     6723.847   72407.195   25946.164  110670.39   131378.3
#   18094.137   20892.406   77502.625   18439.863  183153.38   194089.12
#    2067.9097   7434.9487 185142.75   185101.89     6757.6714  73674.29
#   26781.934  116798.336  139811.6     18933.348   22001.754   78631.95
#   19724.367  185743.89   197587.19     2571.7534   7248.851  190086.08
#  194382.4      7064.39    73981.28    28587.586  125162.125  147750.81
#   20214.898   23697.953   82430.2     20426.684  188020.81   200223.2
#    2562.3901   7503.101  191328.44   193187.34     7687.863   73072.64
#   28804.703  127689.62   153488.56    21116.926   24681.418   85416.57
#   20826.648  192890.97   207710.3      3472.2026   8638.194  195482.75
#  200470.75     7175.566   74958.37    31271.863  135045.61   152773.55
#   21362.473   25820.703   81539.03    19623.094  179691.95   190531.83
#    4761.6636   9367.394  180433.31   181206.25     8236.093   73119.65
#   29176.672  121805.47   141866.89    19745.953   23498.844   77562.55
#   18818.066  177319.36   188018.58     5100.07     9655.597  177955.08
#  181509.17     9310.038   72177.945   28638.77   124696.22   146936.61
#   21179.754   23073.281   82339.92  ]

# %%
def energy_predictions(x_var_index):
    return scaler.inverse_transform(forecast_copies)[:,x_var_index].tolist()

# %%
h1 = energy_predictions(0)
h2 = energy_predictions(1)
h3 = energy_predictions(2)
h4 = energy_predictions(3)
h5 = energy_predictions(4)
h6 = energy_predictions(5)
h7 = energy_predictions(6)
h8 = energy_predictions(7)
h9 = energy_predictions(8)
h10 = energy_predictions(9)
h11 = energy_predictions(10)
h12 = energy_predictions(11)
h13 = energy_predictions(12)
h14 = energy_predictions(13)
h15 = energy_predictions(14)
h16 = energy_predictions(15)
h17 = energy_predictions(16)
h18 = energy_predictions(17)
h19 = energy_predictions(18)
h20 = energy_predictions(19)
h21 = energy_predictions(20)
h22 = energy_predictions(21)
h23 = energy_predictions(22)
h24 = energy_predictions(23)
# date = energy.loc[6881:6992,'date']



d = {'h1': h1, 'h2': h2, 'h3': h3, 'h4': h4, 'h5': h5, 'h6': h6, 'h7': h7, 'h8': h8,
    'h9': h9, 'h10': h10, 'h11': h11, 'h12': h12, 'h13': h13, 'h14': h14, 'h15': h15, 'h16': h16,
    'h17': h17, 'h18': h18, 'h19': h19, 'h20': h20, 'h21': h21, 'h22': h22, 'h23': h23, 'h24': h24}

df = pd.DataFrame(data=d)



print(df)


df.to_excel('energy_naive_predictions5.xlsx')
# Out:
#                 h1             h2             h3             h4  \
# 0     16747.648438   15830.859375   15360.351562   15153.326172
# 1    172108.593750  167303.593750  165238.125000  165538.031250
# 2    178168.390625  173211.734375  171084.062500  171403.734375
# 3      3577.214355    2990.038818    2654.741699    2404.740234
# 4      7062.315918    6387.921387    6016.843262    5778.216797
# ..             ...            ...            ...            ...
# 100  124696.218750  121077.812500  119499.085938  119644.289062
# 101  146936.609375  142761.593750  140954.531250  141172.296875
# 102   21179.753906   20152.042969   19636.035156   19443.470703
# 103   23073.281250   21998.183594   21462.734375   21276.349609
# 104   82339.921875   79781.562500   78637.671875   78644.664062
#
#                 h5             h6             h7             h8  \
# 0     15309.799805   15782.800781   17271.853516   18258.574219
# 1    169441.718750  179888.109375  198414.296875  209473.406250
# 2    175453.578125  186288.984375  205479.703125  216931.687500
# 3      2243.553711    1871.074707    1915.833496    2048.690430
# 4      5701.084961    5552.336426    5979.278809    6338.081055
# ..             ...            ...            ...            ...
# 100  122404.421875  129807.179688  143134.046875  151119.312500
# 101  144468.859375  153299.343750  169065.125000  178492.281250
# 102   19706.845703   20464.363281   22439.447266   23713.515625
# 103   21585.392578   22464.468750   24647.197266   26044.027344
# 104   80383.187500   85066.882812   93748.890625   98988.101562
#
#                 h9            h10  ...            h15            h16  \
# 0     18793.662109   19178.476562  ...   17792.486328   17733.390625
# 1    210338.171875  211415.968750  ...  211695.187500  212346.187500
# 2    217809.312500  218914.140625  ...  219258.296875  219937.000000
# 3      2555.829346    2881.894775  ...    1354.744019    1235.449951
# 4      6852.610840    7194.222656  ...    5704.423828    5601.066895
# ..             ...            ...  ...            ...            ...
# 100  151883.468750  152749.781250  ...  152520.812500  152955.109375
# 101  179303.640625  180269.156250  ...  180278.562500  180814.515625
# 102   24258.005859   24662.589844  ...   23324.099609   23285.265625
# 103   26592.537109   27005.566406  ...   25687.373047   25657.191406
# 104   99662.375000  100339.765625  ...   99656.804688   99897.515625
#
#                h17            h18            h19            h20  \
# 0     18487.488281   19792.382812   21010.181641   21579.246094
# 1    216473.187500  224845.781250  227961.234375  226167.265625
# 2    224195.546875  232843.812500  236033.296875  234147.156250
# 3      1703.621338    2409.358643    3466.283447    4235.676270
# 4      6144.894531    7009.179199    8108.673828    8825.058594
# ..             ...            ...            ...            ...
# 100  156052.781250  162268.484375  164804.828125  163732.000000
# 101  184395.015625  191622.484375  194430.484375  193019.375000
# 102   24135.585938   25642.105469   26914.037109   27415.691406
# 103   26548.617188   28141.277344   29436.337891   29909.195312
# 104  102075.625000  106364.453125  108383.429688  107954.835938
#
#                h21            h22            h23            h24
# 0     21874.216797   21363.650391   20365.330078   18378.990234
# 1    223320.562500  214502.000000  198709.234375  182085.390625
# 2    231177.906250  222035.296875  205665.484375  188470.703125
# 3      4796.982910    4990.701172    5246.561035    4501.088867
# 4      9315.880859    9323.240234    9247.217773    8173.397461
# ..             ...            ...            ...            ...
# 100  161844.062500  155560.890625  144283.031250  132126.187500
# 101  190681.703125  183209.218750  169813.484375  155561.250000
# 102   27621.041016   26873.462891   25453.091797   23049.173828
# 103   30076.251953   29227.419922   27626.732422   25044.416016
# 104  106923.421875  102905.273438   95660.843750   87494.656250
#
# [105 rows x 24 columns]

# %% [markdown]
# ### 13110; 5/25-5/31 2017
