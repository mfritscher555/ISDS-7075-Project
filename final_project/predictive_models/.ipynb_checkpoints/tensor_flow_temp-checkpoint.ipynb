# %% [markdown]
# # Predicting Temperature
#
# In order to effectively predict the energy demand, we must first predict the temperatures.

# %% [markdown]
# Importing the necessary packages; tensorflow/keras are used to do the predictions, specifically the method used was called LSTM - i.e., Long Short-term memory.

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense, Dropout
from matplotlib import pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import seaborn as sns

# %%
# Reading in data
temps = pd.read_excel(r"C:\Users\Matthew\PycharmProjects\ISDS-7075-Project\final_project\datasets\dataset.xlsx",
                      sheet_name="temperature_history")

# %%
# Creating dummy variables for each of the 9 weather stations
temps = pd.get_dummies(temps, columns=["station_id"])

# %%
# Creating a date field
temps["date"] = pd.to_datetime(temps[["year", "month", "day"]], format='%Y-%m-%d', errors='coerce')

# Leap year values are causing problems.... manually replacing
# temps["date"].fillna('2015-02-29', inplace=True)


train_dates = temps["date"]
# print(train_dates.info())

# %%
# Identifying which cols for training (h1 is the y in this example)
cols = list(temps)[4:-1]
print(cols)


# New df with only x vars
df_for_training = temps[cols].astype(float)
df_for_training = df_for_training.iloc[0:14715,:]
# Out:
# ['h1', 'h2', 'h3', 'h4', 'h5', 'h6', 'h7', 'h8', 'h9', 'h10', 'h11', 'h12', 'h13', 'h14', 'h15', 'h16', 'h17', 'h18', 'h19', 'h20', 'h21', 'h22', 'h23', 'h24', 'station_id_1', 'station_id_2', 'station_id_3', 'station_id_4', 'station_id_5', 'station_id_6', 'station_id_7', 'station_id_8', 'station_id_9']

# %%
# LTSM uses sigmoid and tanh that are sensitive to magnitude, so values need to be normalized
scaler = StandardScaler()
scaler = scaler.fit(df_for_training)
df_for_training_scaled = scaler.transform(df_for_training)

# %%
trainX = []
trainY = []


n_future = 7
n_past = 21



for i in range(n_past, len(df_for_training_scaled) - n_future + 1):
    trainX.append(df_for_training_scaled[i - n_past:i, 0:df_for_training.shape[1]])
    trainY.append(df_for_training_scaled[i + n_future - 1:i + n_future, 0])

trainX, trainY = np.array(trainX), np.array(trainY)

# %%
# define Autoencoder model

model = Sequential()
model.add(LSTM(64, activation='relu', input_shape=(trainX.shape[1], trainX.shape[2]), return_sequences=True))
model.add(LSTM(32, activation='relu', return_sequences=False))
model.add(Dropout(0.2))
model.add(Dense(trainY.shape[1]))

model.compile(optimizer='adam', loss='mse')
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  lstm_8 (LSTM)               (None, 21, 64)            25088
#
#  lstm_9 (LSTM)               (None, 32)                12416
#
#  dropout_4 (Dropout)         (None, 32)                0
#
#  dense_4 (Dense)             (None, 1)                 33
#
# ...
# Total params: 37,537
# Trainable params: 37,537
# Non-trainable params: 0
# _________________________________________________________________

# %%
# # Date and h1 prediction columns

# df_forecast = pd.DataFrame({'Date':np.array(forecast_dates), 'h1':y_pred_future})
# df_forecast['Date'] = pd.to_datetime(df_forecast['Date'])

# print(df_forecast)

# %%
# fit model
history = model.fit(x=trainX, y=trainY, epochs=10, batch_size=16, validation_split=0.1, verbose=1)
# Out:
# Epoch 1/10
# 827/827 [==============================] - 10s 13ms/step - loss: 0.0583 - val_loss: 0.0386
# Epoch 2/10
# 827/827 [==============================] - 10s 13ms/step - loss: 0.0512 - val_loss: 0.0298
# Epoch 3/10
# 827/827 [==============================] - 11s 13ms/step - loss: 0.0478 - val_loss: 0.0315
# Epoch 4/10
# 827/827 [==============================] - 11s 13ms/step - loss: 0.0422 - val_loss: 0.0222
# Epoch 5/10
# 827/827 [==============================] - 11s 13ms/step - loss: 0.0385 - val_loss: 0.0184
# Epoch 6/10
# 827/827 [==============================] - 11s 13ms/step - loss: 0.0350 - val_loss: 0.0166
# Epoch 7/10
# 827/827 [==============================] - 10s 12ms/step - loss: 0.0329 - val_loss: 0.0165
# Epoch 8/10
# 827/827 [==============================] - 10s 13ms/step - loss: 0.0318 - val_loss: 0.0213
# Epoch 9/10
# 827/827 [==============================] - 10s 12ms/step - loss: 0.0304 - val_loss: 0.0148
# Epoch 10/10
# ...

# %%
# plotting training/validation loss

plt.plot(history.history['loss'], label='Training loss')
plt.plot(history.history['val_loss'], label='Validation loss')
plt.legend()
plt.show()

# %%
# Forecasting
# start with the last day in training set and predict future
n_future = 63
forecast_period_dates = pd.date_range(list(train_dates)[-1], periods=n_future, freq='1d').tolist()

forecast = model.predict(trainX[-n_future:])
# Out:
# 2/2 [==============================] - 0s 8ms/step

# %%
# Perform inverse transformation to rescale back to original range

forecast_copies = np.repeat(forecast, df_for_training.shape[1], axis=-1)
h1_future = scaler.inverse_transform(forecast_copies)[:,0]

print(h1_future)
# Out:
# [72.04314  80.27293  72.44091  75.911255 80.976166 78.657845 79.75997
#  77.77943  79.63787  69.93797  79.37329  72.775925 72.21502  78.82628
#  72.531006 78.701126 76.22245  76.96744  65.89495  77.317665 65.338135
#  70.43044  73.84369  72.38326  71.4714   71.23381  71.63374  64.989235
#  77.826    66.00087  69.501755 72.34902  69.2599   72.113075 72.887436
#  74.0706   65.19208  74.411705 67.00702  71.92912  76.97596  72.26364
#  74.940216 71.727196 73.42004  69.16458  79.83687  70.818886 75.60891
#  79.292244 76.22136  78.49931  77.89594  78.72924  73.018715 81.15415
#  73.525406 77.785774 79.437904 77.933876 79.184074 77.89883  78.071976]

# %%
def temp_predictions(x_var_index):
    return scaler.inverse_transform(forecast_copies)[:,x_var_index].tolist()

# %% [markdown]
# Creating the columns for hourly prediction by calling the above function

# %%
h1 = temp_predictions(0)
h2 = temp_predictions(1)
h3 = temp_predictions(2)
h4 = temp_predictions(3)
h5 = temp_predictions(4)
h6 = temp_predictions(5)
h7 = temp_predictions(6)
h8 = temp_predictions(7)
h9 = temp_predictions(8)
h10 = temp_predictions(9)
h11 = temp_predictions(10)
h12 = temp_predictions(11)
h13 = temp_predictions(12)
h14 = temp_predictions(13)
h15 = temp_predictions(14)
h16 = temp_predictions(15)
h17 = temp_predictions(16)
h18 = temp_predictions(17)
h19 = temp_predictions(18)
h20 = temp_predictions(19)
h21 = temp_predictions(20)
h22 = temp_predictions(21)
h23 = temp_predictions(22)
h24 = temp_predictions(23)
date = temps.loc[14715:14778,'date']



d = {'date':date,'h1': h1, 'h2': h2, 'h3': h3, 'h4': h4, 'h5': h5, 'h6': h6, 'h7': h7, 'h8': h8,
    'h9': h9, 'h10': h10, 'h11': h11, 'h12': h12, 'h13': h13, 'h14': h14, 'h15': h15, 'h16': h16,
    'h17': h17, 'h18': h18, 'h19': h19, 'h20': h20, 'h21': h21, 'h22': h22, 'h23': h23, 'h24': h24}

df = pd.DataFrame(data=d)



print(df)
# Out:
#             date         h1         h2         h3         h4         h5  \
# 14715 2019-06-23  72.043137  71.424881  70.891228  70.409615  69.990494
# 14716 2019-06-23  80.272926  79.649673  79.119431  78.644257  78.239273
# 14717 2019-06-23  72.440910  71.822418  71.288933  70.807632  70.389191
# 14718 2019-06-23  75.911255  75.290649  74.758598  74.280014  73.867538
# 14719 2019-06-23  80.976166  80.352486  79.822533  79.347900  78.944138
# ...          ...        ...        ...        ...        ...        ...
# 14773 2019-06-29  79.437904  78.815163  78.284569  77.808739  77.402328
# 14774 2019-06-29  77.933876  77.312042  76.780830  76.303825  75.894829
# 14775 2019-06-29  79.184074  78.561485  78.030785  77.554756  77.147911
# 14776 2019-06-29  77.898827  77.277016  76.745789  76.268753  75.859695
# 14777 2019-06-29  78.071976  77.450058  76.918907  76.442009  76.033249
#
#               h6         h7         h8         h9  ...        h15        h16  \
# ...

# %%
new = temps.append(df)

# This is commented out because I do not want to overwrite what is in the file
# new.to_excel('temp_predictions(1).xlsx')
# Out:
# C:\Users\Matthew\AppData\Local\Temp\ipykernel_24116\3900349292.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new = temps.append(df)

# %% [markdown]
# Manually fixed where the predictions go in the excel file... re-reading in the file in order to plot a line (and see if the predictions are in the right ball park).

# %%
# These are the predictions (at hour 1)
df["h1"].plot.line()
# Out:
# <AxesSubplot: >

# %%
# These are the actual and predicted h1 together

new_df = pd.read_excel('temp_predictions(1).xlsx')
plt.plot(temps.loc[14500:14777,"h1"],color='gold', label='historic')
plt.plot(new_df.loc[14715:14777,"h1"], color='purple', label='predicted')
plt.legend()
plt.show()
